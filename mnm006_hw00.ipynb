# %% [markdown]
# #### Задание №1

# %%
from sympy import *
init_printing()
# %matplotlib inline

nroots((sin)**2, 40)

# %%
N((sin(sqrt(log(3)) / ((cos(2) +3 )**3 * (log(8, 3) + 2)**5) - real_root(2, 6)))**2).evalf(40)
# Out:
# 0.8120549572776580848909588894457556307316

# %% [markdown]
# #### Задание №2

# %%
var('u x y z')
expand((u + z)**2 * (2 * x- y)**3 * (2 * x + y))
# Out:
#     2  4       2  3        2    3    2  4         4           3              3
# 16⋅u ⋅x  - 16⋅u ⋅x ⋅y + 4⋅u ⋅x⋅y  - u ⋅y  + 32⋅u⋅x ⋅z - 32⋅u⋅x ⋅y⋅z + 8⋅u⋅x⋅y
#
#           4         4  2       3    2        3  2    4  2
# ⋅z - 2⋅u⋅y ⋅z + 16⋅x ⋅z  - 16⋅x ⋅y⋅z  + 4⋅x⋅y ⋅z  - y ⋅z

# %% [markdown]
# #### Задание №3

# %%
factor(12*u**3*x**3 + 72*u**3*x**2*y + 144*u**3*x*y**2 + 96*u**3*y**3 + 4*u**2*x**4 + 12*u**2*x**3*y - 24*u**2*x**2*y**2 - 112*u**2*x*y**3 - 96*u**2*y**4 - 4*u*x**4*y - 21*u*x**3*y**2 - 30*u*x**2*y**3 + 4*u*x*y**4 + 24*u*y**5 + x**4*y**2 + 6*x**3*y**3 + 12*x**2*y**4 + 8*x*y**5)
# Out:
#           2                    3
# (-2⋅u + y) ⋅(3⋅u + x)⋅(x + 2⋅y)

# %% [markdown]
# #### Задание №4

# %%
solveset(20 * x**4 + 47 * x**3 + 119 * x**2 +127 * x - 40, x)
# Out:
# ⎧             1   √19⋅ⅈ    1   √19⋅ⅈ⎫
# ⎨-8/5, 1/4, - ─ - ─────, - ─ + ─────⎬
# ⎩             2     2      2     2  ⎭

# %% [markdown]
# #### Задание №5

# %%
var('y')

plot_implicit(-x**8 + 2 * x**4 - y**8 + y**4, aspect_ratio = (1, 1))

# %% [markdown]
# #### Задание №6

# %%
var('t')
solveset(4 * sin(3 * t), t, domain = S.Reals)
# Out:
# ⎧2⋅n⋅π │      ⎫   ⎧2⋅n⋅π   π │      ⎫
# ⎨───── │ n ∊ ℤ⎬ ∪ ⎨───── + ─ │ n ∊ ℤ⎬
# ⎩  3   │      ⎭   ⎩  3     3 │      ⎭

# %%
solveset(3 * sin(2 * t), t, domain = S.Reals)
# Out:
#                 ⎧      π │      ⎫
# {n⋅π │ n ∊ ℤ} ∪ ⎨n⋅π + ─ │ n ∊ ℤ⎬
#                 ⎩      2 │      ⎭

# %%
plotting.plot_parametric(4 * sin(3 *t), 3 * sin(2 * t), (t, 0, 2 * pi), aspect_ratio = (1, 1))
